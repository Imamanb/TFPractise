# %% [markdown]
# <a href="https://colab.research.google.com/github/Imamanb/TFPractise/blob/master/TF_HousingPRices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
model = tf.keras.Sequential([keras.layers.Dense(units = 1, input_shape=[1])])
model.compile(optimizer='sgd' , loss='mean_squared_error')

# %%
xs = np.array([1,2,3,4,5,6,8], dtype=int)
ys = np.array([1 , 1.50, 2.00, 2.50, 3.00,3.5,4.5], dtype=float)

# %%
model.fit(xs, ys, epochs= 500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0039
# Epoch 2/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0027
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 4/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0022
# Epoch 5/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0022
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 7/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 8/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 9/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 10/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 11/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0021
# Epoch 12/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0020
# ...

# %%
print(model.predict([7.0]))
# Out:
# [[3.996336]]
